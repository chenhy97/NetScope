# %%
import numpy as np
import math

# %%
# random_sequence = np.random.randint(1000,2000, size = 10)
random_sequence = np.array([1896,   1026,   1367,   1389,  1365,  1752,   1651,   1380,   1132,   1437])

# %%
append_random_sequence = np.append(random_sequence,np.random.randint(1000,2000, size = 200))
# append_random_sequence = np.append(random_sequence,[1000,900,200,1500,159])
# append_random_sequence = np.append(random_sequence,[10,90,20,150,159])

# %%
append_random_sequence
# Out:
# array([1896, 1026, 1367, 1389, 1365, 1752, 1651, 1380, 1132, 1437, 1341,
#        1140, 1202, 1290, 1794, 1258, 1716, 1418, 1982, 1488, 1670, 1523,
#        1428, 1244, 1287, 1702, 1846, 1224, 1187, 1285, 1353, 1453, 1354,
#        1462, 1204, 1939, 1947, 1504, 1225, 1778, 1713, 1554, 1082, 1354,
#        1704, 1537, 1603, 1985, 1038, 1108, 1283, 1076, 1997, 1573, 1466,
#        1502, 1492, 1578, 1034, 1177, 1080, 1068, 1298, 1326, 1643, 1702,
#        1060, 1708, 1710, 1710, 1645, 1170, 1497, 1321, 1879, 1439, 1089,
#        1070, 1129, 1008, 1141, 1965, 1522, 1373, 1026, 1893, 1853, 1117,
#        1514, 1709, 1125, 1432, 1523, 1968, 1375, 1224, 1302, 1173, 1473,
#        1111, 1780, 1538, 1147, 1757, 1694, 1866, 1966, 1630, 1701, 1782,
#        1599, 1752, 1464, 1013, 1914, 1082, 1459, 1028, 1282, 1592, 1806,
#        1093, 1696, 1256, 1692, 1187, 1395, 1317, 1758, 1227, 1047, 1474,
#        1282, 1391, 1314, 1345, 1496, 1708, 1979, 1093, 1013, 1168, 1719,
#        1191, 1552, 1185, 1250, 1033, 1106, 1509, 1067, 1919, 1048, 1380,
#        1634, 1280, 1150, 1096, 1863, 1995, 1308, 1065, 1476, 1223, 1494,
#        1134, 1602, 1802, 1937, 1022, 1316, 1143, 1092, 1115, 1235, 1907,
#        1685, 1949, 1831, 1283, 1207, 1533, 1334, 1935, 1305, 1842, 1470,
#        1310, 1440, 1023, 1099, 1350, 1114, 1021, 1075, 1390, 1263, 1179,
#        1693, 1038, 1850, 1095, 1387, 1911, 1762, 1640, 1741, 1752, 1109,
#        1731])

# %%
def update(p, x_n, current_quantile, seq_size, max_gap_record, min_gap_record, min_gap, c_minus, c_plus, x_max, x_min):
    max_value = max_gap_record[0]
    max_prev_value = max_gap_record[1]
    min_value = min_gap_record[0]
    min_prev_value = min_gap_record[1]
    # if x_n == max_prev_value:
    #     lambda_x = max_value - max_prev_value
    # elif x_n == min_prev_value:
    #     lambda_x = min_prev_value - min_value
    # else:
    #     lambda_x = min_gap
    lambda_x = min_gap
    if x_n < current_quantile:
        floor_value = math.floor(seq_size*p)
        round_value = round(seq_size*p)
        if floor_value % 2 == 0 and seq_size*p - floor_value == 0.5:
            round_value = round(seq_size*p) + 1
        print("c_minux+1: {}, seq_size*p: {}, round value: {}".format(c_minus + 1, seq_size * p, round_value))
        if c_minus + 1 >= seq_size * p:
            if current_quantile == min_prev_value:
                current_quantile = min_value
                min_gap_record = [x_min, min_value]
            elif current_quantile == max_value:
                current_quantile = max_prev_value
                print("*****", max_gap_record, min_gap_record)
                if x_n < max_prev_value:
                    if x_n > min_prev_value:
                        max_gap_record = [max_prev_value, x_n]
                    else:
                        max_gap_record = [max_prev_value,max_prev_value - lambda_x]
                else:
                    max_gap_record = [x_n,max_prev_value]
            else:
                print("============= minus", current_quantile, lambda_x)
                current_quantile = current_quantile - lambda_x
            c_plus = c_plus + 1
        else:
            c_minus = c_minus + 1
    elif x_n >= current_quantile:
        print("c_plus+1: {}, seq_size*(1-p): {}".format(c_plus + 1, seq_size * (1-p)))
        if c_plus + 1 > (seq_size * (1 - p)):
            if current_quantile == max_prev_value:
                current_quantile = max_value
                max_gap_record = [x_max, max_value]
                print("!!!!!!!max_gap_record", max_gap_record)
            else:
                print("~~~~~~~~~~~ pluss", current_quantile, lambda_x)

                current_quantile = current_quantile + lambda_x
            print("current_quantile", current_quantile)
            c_minus = c_minus + 1
        else:
            c_plus = c_plus + 1
    return current_quantile, c_minus, c_plus, max_gap_record, min_gap_record

# %%
append_random_sequence
# Out:
# array([1896, 1026, 1367, 1389, 1365, 1752, 1651, 1380, 1132, 1437, 1341,
#        1140, 1202, 1290, 1794, 1258, 1716, 1418, 1982, 1488, 1670, 1523,
#        1428, 1244, 1287, 1702, 1846, 1224, 1187, 1285, 1353, 1453, 1354,
#        1462, 1204, 1939, 1947, 1504, 1225, 1778, 1713, 1554, 1082, 1354,
#        1704, 1537, 1603, 1985, 1038, 1108, 1283, 1076, 1997, 1573, 1466,
#        1502, 1492, 1578, 1034, 1177, 1080, 1068, 1298, 1326, 1643, 1702,
#        1060, 1708, 1710, 1710, 1645, 1170, 1497, 1321, 1879, 1439, 1089,
#        1070, 1129, 1008, 1141, 1965, 1522, 1373, 1026, 1893, 1853, 1117,
#        1514, 1709, 1125, 1432, 1523, 1968, 1375, 1224, 1302, 1173, 1473,
#        1111, 1780, 1538, 1147, 1757, 1694, 1866, 1966, 1630, 1701, 1782,
#        1599, 1752, 1464, 1013, 1914, 1082, 1459, 1028, 1282, 1592, 1806,
#        1093, 1696, 1256, 1692, 1187, 1395, 1317, 1758, 1227, 1047, 1474,
#        1282, 1391, 1314, 1345, 1496, 1708, 1979, 1093, 1013, 1168, 1719,
#        1191, 1552, 1185, 1250, 1033, 1106, 1509, 1067, 1919, 1048, 1380,
#        1634, 1280, 1150, 1096, 1863, 1995, 1308, 1065, 1476, 1223, 1494,
#        1134, 1602, 1802, 1937, 1022, 1316, 1143, 1092, 1115, 1235, 1907,
#        1685, 1949, 1831, 1283, 1207, 1533, 1334, 1935, 1305, 1842, 1470,
#        1310, 1440, 1023, 1099, 1350, 1114, 1021, 1075, 1390, 1263, 1179,
#        1693, 1038, 1850, 1095, 1387, 1911, 1762, 1640, 1741, 1752, 1109,
#        1731])

# %%
p = 0.9
x_sum = 0
c_minus = 0
c_plus = 0
min_gap = 2
max_gap = -1
x_prev_max = -1
x_prev_min = -1
x_max = -1
x_min = -1
for  i in range(len(append_random_sequence)):
    x_n = append_random_sequence[i]
    seq_size = i + 1
    if i == 0:
        current_quantile = x_n
        x_prev_max = x_n
        x_prev_min = x_n
        x_max = x_n
        x_min = x_n
        continue
    elif i == 1 or i == 2:
        # min_gap = [-1,-1]
        min_gap = abs(x_n - x_prev_max)
        if x_n < x_min:
            x_prev_min = x_min
            x_min = x_n
            record_min_gap = [x_min,x_prev_min]
        else:
            x_prev_min = x_n
            record_min_gap = [x_min, x_prev_min]
        if x_n > x_max:
            x_prev_max = x_max
            x_max = x_n
            record_max_gap = [x_max,x_prev_max]
        else:
            x_prev_max = x_n
            record_max_gap = [x_max, x_prev_max]
    # elif i == 2:
    #     print("i==2", x_n, x_prev_max, x_max, x_prev_min, x_min)
    else:
        x_prev_max = record_max_gap[1]
        x_prev_min = record_min_gap[1]
        print("@@@@@@@",i, record_max_gap, x_prev_max)
        
        gap = abs(x_n - x_prev_max)
        if min_gap> gap and gap > 0:
            min_gap = gap
        if x_n > x_max:
            print("--- x_n:{}, x_prev_max:{}, x_max:{}".format(x_n, x_prev_max, x_max))
            gap_before = x_max - x_prev_max
            gap_after = x_n - x_max
            if gap_after > gap_before:
                x_prev_max = x_max
                x_max = x_n
                record_max_gap = [x_max, x_prev_max]
            x_max = x_n
        elif x_n < x_min:
            print("++= x_n:{}, x_prev_min:{}, x_min: {}".format(x_n, x_prev_min, x_min))
            gap_before = x_prev_min - x_min
            gap_after = x_min - x_n
            if gap_after > gap_before:
                x_prev_min = x_min
                x_min = x_n
                record_min_gap = [x_min, x_prev_min]
            x_min = x_n
        elif x_n > x_prev_max and x_n < x_max:
            if x_max == current_quantile:
                print("i",x_n)
                record_max_gap = [x_max, x_n]
            else:
                gap_before = x_n - x_prev_max
                gap_after = record_max_gap[0] - x_n
                if gap_after > gap_before:
                    print("k gap_before: [{},{}] ; gap_after: [{},{}]".format(x_prev_max, x_n, x_n, record_max_gap[0]), x_n,x_prev_max)
                    x_prev_max = x_n
                    record_max_gap = [record_max_gap[0], x_n]
                else:
                    print("j",x_n)
                    record_max_gap = [x_n, x_prev_max]
        elif x_n < x_prev_min and x_n > x_min:
            gap_before = x_n - record_min_gap[0]
            gap_after = x_prev_min - x_n
            if gap_after > gap_before:
                print("jjjj", x_n, x_prev_min)
                record_min_gap = [x_n, x_prev_min]
            else:
                print("tk gap_before: [{},{}]; gap_after: [{},{}]".format(x_n, record_min_gap[0], x_n, x_prev_min), x_n, x_prev_max)
                x_prev_min = x_n
                record_min_gap = [record_min_gap[0], x_n]
        print("record_max_gap:{}, x_prev_max: {}, x_max: {}, x_n:{}".format( record_max_gap, x_prev_max, x_max, x_n))
        print("record_min_gap:{}, x_prev_min: {}, x_min: {}, x_n:{}".format( record_min_gap, x_prev_min, x_min, x_n))

    print("Before Round% {},current_quantile:{},  x_n:{}, record_min_gap: {}, record_max_gap:{}, min_gap:{}, c_minus:{}, c_plus:{} ".format(i,current_quantile, x_n,record_min_gap, record_max_gap,  min_gap, c_minus, c_plus), seq_size )
    current_quantile, c_minus, c_plus, record_max_gap, record_min_gap = update(p, x_n, current_quantile,seq_size, record_max_gap, record_min_gap, min_gap, c_minus, c_plus, x_max, x_min)
    # x_prev_max = x_n
    print("After Round% {}, current_quantile:{}, record_min_gap: {}, record_max_gap:{}, min_gap:{}, c_minus:{}, c_plus:{} ".format(i, current_quantile, record_min_gap, record_max_gap,  min_gap, c_minus, c_plus)  )
# Out:
# Before Round% 1,current_quantile:1896,  x_n:1026, record_min_gap: [1026, 1896], record_max_gap:[1896, 1026], min_gap:870, c_minus:0, c_plus:0  2
# c_minux+1: 1, seq_size*p: 1.8, round value: 2
# After Round% 1, current_quantile:1896, record_min_gap: [1026, 1896], record_max_gap:[1896, 1026], min_gap:870, c_minus:1, c_plus:0
# Before Round% 2,current_quantile:1896,  x_n:1367, record_min_gap: [1026, 1367], record_max_gap:[1896, 1367], min_gap:341, c_minus:1, c_plus:0  3
# c_minux+1: 2, seq_size*p: 2.7, round value: 3
# After Round% 2, current_quantile:1896, record_min_gap: [1026, 1367], record_max_gap:[1896, 1367], min_gap:341, c_minus:2, c_plus:0
# @@@@@@@ 3 [1896, 1367] 1367
# i 1389
# record_max_gap:[1896, 1389], x_prev_max: 1367, x_max: 1896, x_n:1389
# record_min_gap:[1026, 1367], x_prev_min: 1367, x_min: 1026, x_n:1389
# Before Round% 3,current_quantile:1896,  x_n:1389, record_min_gap: [1026, 1367], record_max_gap:[1896, 1389], min_gap:22, c_minus:2, c_plus:0  4
# c_minux+1: 3, seq_size*p: 3.6, round value: 4
# After Round% 3, current_quantile:1896, record_min_gap: [1026, 1367], record_max_gap:[1896, 1389], min_gap:22, c_minus:3, c_plus:0
# @@@@@@@ 4 [1896, 1389] 1389
# tk gap_before: [1365,1026]; gap_after: [1365,1367] 1365 1389
# record_max_gap:[1896, 1389], x_prev_max: 1389, x_max: 1896, x_n:1365
# record_min_gap:[1026, 1365], x_prev_min: 1365, x_min: 1026, x_n:1365
# Before Round% 4,current_quantile:1896,  x_n:1365, record_min_gap: [1026, 1365], record_max_gap:[1896, 1389], min_gap:22, c_minus:3, c_plus:0  5
# c_minux+1: 4, seq_size*p: 4.5, round value: 5
# After Round% 4, current_quantile:1896, record_min_gap: [1026, 1365], record_max_gap:[1896, 1389], min_gap:22, c_minus:4, c_plus:0
# @@@@@@@ 5 [1896, 1389] 1389
# i 1752
# record_max_gap:[1896, 1752], x_prev_max: 1389, x_max: 1896, x_n:1752
# record_min_gap:[1026, 1365], x_prev_min: 1365, x_min: 1026, x_n:1752
# Before Round% 5,current_quantile:1896,  x_n:1752, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:4, c_plus:0  6
# c_minux+1: 5, seq_size*p: 5.4, round value: 5
# After Round% 5, current_quantile:1896, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:5, c_plus:0
# @@@@@@@ 6 [1896, 1752] 1752
# record_max_gap:[1896, 1752], x_prev_max: 1752, x_max: 1896, x_n:1651
# record_min_gap:[1026, 1365], x_prev_min: 1365, x_min: 1026, x_n:1651
# Before Round% 6,current_quantile:1896,  x_n:1651, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:5, c_plus:0  7
# c_minux+1: 6, seq_size*p: 6.3, round value: 6
# After Round% 6, current_quantile:1896, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:6, c_plus:0
# @@@@@@@ 7 [1896, 1752] 1752
# record_max_gap:[1896, 1752], x_prev_max: 1752, x_max: 1896, x_n:1380
# record_min_gap:[1026, 1365], x_prev_min: 1365, x_min: 1026, x_n:1380
# Before Round% 7,current_quantile:1896,  x_n:1380, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:6, c_plus:0  8
# c_minux+1: 7, seq_size*p: 7.2, round value: 7
# After Round% 7, current_quantile:1896, record_min_gap: [1026, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:7, c_plus:0
# @@@@@@@ 8 [1896, 1752] 1752
# jjjj 1132 1365
# record_max_gap:[1896, 1752], x_prev_max: 1752, x_max: 1896, x_n:1132
# record_min_gap:[1132, 1365], x_prev_min: 1365, x_min: 1026, x_n:1132
# Before Round% 8,current_quantile:1896,  x_n:1132, record_min_gap: [1132, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:7, c_plus:0  9
# c_minux+1: 8, seq_size*p: 8.1, round value: 8
# After Round% 8, current_quantile:1896, record_min_gap: [1132, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:8, c_plus:0
# @@@@@@@ 9 [1896, 1752] 1752
# record_max_gap:[1896, 1752], x_prev_max: 1752, x_max: 1896, x_n:1437
# record_min_gap:[1132, 1365], x_prev_min: 1365, x_min: 1026, x_n:1437
# Before Round% 9,current_quantile:1896,  x_n:1437, record_min_gap: [1132, 1365], record_max_gap:[1896, 1752], min_gap:22, c_minus:8, c_plus:0  10
# c_minux+1: 9, seq_size*p: 9.0, round value: 9
# ***** [1896, 1752] [1132, 1365]
# After Round% 9, current_quantile:1752, record_min_gap: [1132, 1365], record_max_gap:[1752, 1437], min_gap:22, c_minus:8, c_plus:1
# @@@@@@@ 10 [1752, 1437] 1437
# tk gap_before: [1341,1132]; gap_after: [1341,1365] 1341 1437
# record_max_gap:[1752, 1437], x_prev_max: 1437, x_max: 1896, x_n:1341
# record_min_gap:[1132, 1341], x_prev_min: 1341, x_min: 1026, x_n:1341
# Before Round% 10,current_quantile:1752,  x_n:1341, record_min_gap: [1132, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:8, c_plus:1  11
# c_minux+1: 9, seq_size*p: 9.9, round value: 10
# After Round% 10, current_quantile:1752, record_min_gap: [1132, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:9, c_plus:1
# @@@@@@@ 11 [1752, 1437] 1437
# jjjj 1140 1341
# record_max_gap:[1752, 1437], x_prev_max: 1437, x_max: 1896, x_n:1140
# record_min_gap:[1140, 1341], x_prev_min: 1341, x_min: 1026, x_n:1140
# Before Round% 11,current_quantile:1752,  x_n:1140, record_min_gap: [1140, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:9, c_plus:1  12
# c_minux+1: 10, seq_size*p: 10.8, round value: 11
# After Round% 11, current_quantile:1752, record_min_gap: [1140, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:10, c_plus:1
# @@@@@@@ 12 [1752, 1437] 1437
# jjjj 1202 1341
# record_max_gap:[1752, 1437], x_prev_max: 1437, x_max: 1896, x_n:1202
# record_min_gap:[1202, 1341], x_prev_min: 1341, x_min: 1026, x_n:1202
# Before Round% 12,current_quantile:1752,  x_n:1202, record_min_gap: [1202, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:10, c_plus:1  13
# c_minux+1: 11, seq_size*p: 11.700000000000001, round value: 12
# After Round% 12, current_quantile:1752, record_min_gap: [1202, 1341], record_max_gap:[1752, 1437], min_gap:22, c_minus:11, c_plus:1
# @@@@@@@ 13 [1752, 1437] 1437
# tk gap_before: [1290,1202]; gap_after: [1290,1341] 1290 1437
# record_max_gap:[1752, 1437], x_prev_max: 1437, x_max: 1896, x_n:1290
# record_min_gap:[1202, 1290], x_prev_min: 1290, x_min: 1026, x_n:1290
# Before Round% 13,current_quantile:1752,  x_n:1290, record_min_gap: [1202, 1290], record_max_gap:[1752, 1437], min_gap:22, c_minus:11, c_plus:1  14
# c_minux+1: 12, seq_size*p: 12.6, round value: 13
# After Round% 13, current_quantile:1752, record_min_gap: [1202, 1290], record_max_gap:[1752, 1437], min_gap:22, c_minus:12, c_plus:1
# @@@@@@@ 14 [1752, 1437] 1437
# j 1794
# record_max_gap:[1794, 1437], x_prev_max: 1437, x_max: 1896, x_n:1794
# record_min_gap:[1202, 1290], x_prev_min: 1290, x_min: 1026, x_n:1794
# Before Round% 14,current_quantile:1752,  x_n:1794, record_min_gap: [1202, 1290], record_max_gap:[1794, 1437], min_gap:22, c_minus:12, c_plus:1  15
# c_plus+1: 2, seq_size*(1-p): 1.4999999999999996
# ~~~~~~~~~~~ pluss 1752 22
# current_quantile 1774
# After Round% 14, current_quantile:1774, record_min_gap: [1202, 1290], record_max_gap:[1794, 1437], min_gap:22, c_minus:13, c_plus:1
# @@@@@@@ 15 [1794, 1437] 1437
# tk gap_before: [1258,1202]; gap_after: [1258,1290] 1258 1437
# record_max_gap:[1794, 1437], x_prev_max: 1437, x_max: 1896, x_n:1258
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1258
# Before Round% 15,current_quantile:1774,  x_n:1258, record_min_gap: [1202, 1258], record_max_gap:[1794, 1437], min_gap:22, c_minus:13, c_plus:1  16
# c_minux+1: 14, seq_size*p: 14.4, round value: 14
# After Round% 15, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1794, 1437], min_gap:22, c_minus:14, c_plus:1
# @@@@@@@ 16 [1794, 1437] 1437
# j 1716
# record_max_gap:[1716, 1437], x_prev_max: 1437, x_max: 1896, x_n:1716
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1716
# Before Round% 16,current_quantile:1774,  x_n:1716, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:22, c_minus:14, c_plus:1  17
# c_minux+1: 15, seq_size*p: 15.3, round value: 15
# After Round% 16, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:22, c_minus:15, c_plus:1
# @@@@@@@ 17 [1716, 1437] 1437
# record_max_gap:[1716, 1437], x_prev_max: 1437, x_max: 1896, x_n:1418
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1418
# Before Round% 17,current_quantile:1774,  x_n:1418, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:19, c_minus:15, c_plus:1  18
# c_minux+1: 16, seq_size*p: 16.2, round value: 16
# After Round% 17, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:19, c_minus:16, c_plus:1
# @@@@@@@ 18 [1716, 1437] 1437
# --- x_n:1982, x_prev_max:1437, x_max:1896
# record_max_gap:[1716, 1437], x_prev_max: 1437, x_max: 1982, x_n:1982
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1982
# Before Round% 18,current_quantile:1774,  x_n:1982, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:19, c_minus:16, c_plus:1  19
# c_plus+1: 2, seq_size*(1-p): 1.8999999999999995
# ~~~~~~~~~~~ pluss 1774 19
# current_quantile 1793
# After Round% 18, current_quantile:1793, record_min_gap: [1202, 1258], record_max_gap:[1716, 1437], min_gap:19, c_minus:17, c_plus:1
# @@@@@@@ 19 [1716, 1437] 1437
# k gap_before: [1437,1488] ; gap_after: [1488,1716] 1488 1437
# record_max_gap:[1716, 1488], x_prev_max: 1488, x_max: 1982, x_n:1488
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1488
# Before Round% 19,current_quantile:1793,  x_n:1488, record_min_gap: [1202, 1258], record_max_gap:[1716, 1488], min_gap:19, c_minus:17, c_plus:1  20
# c_minux+1: 18, seq_size*p: 18.0, round value: 18
# ============= minus 1793 19
# After Round% 19, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1716, 1488], min_gap:19, c_minus:17, c_plus:2
# @@@@@@@ 20 [1716, 1488] 1488
# j 1670
# record_max_gap:[1670, 1488], x_prev_max: 1488, x_max: 1982, x_n:1670
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1670
# Before Round% 20,current_quantile:1774,  x_n:1670, record_min_gap: [1202, 1258], record_max_gap:[1670, 1488], min_gap:19, c_minus:17, c_plus:2  21
# c_minux+1: 18, seq_size*p: 18.900000000000002, round value: 19
# After Round% 20, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1670, 1488], min_gap:19, c_minus:18, c_plus:2
# @@@@@@@ 21 [1670, 1488] 1488
# k gap_before: [1488,1523] ; gap_after: [1523,1670] 1523 1488
# record_max_gap:[1670, 1523], x_prev_max: 1523, x_max: 1982, x_n:1523
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1523
# Before Round% 21,current_quantile:1774,  x_n:1523, record_min_gap: [1202, 1258], record_max_gap:[1670, 1523], min_gap:19, c_minus:18, c_plus:2  22
# c_minux+1: 19, seq_size*p: 19.8, round value: 20
# After Round% 21, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1670, 1523], min_gap:19, c_minus:19, c_plus:2
# @@@@@@@ 22 [1670, 1523] 1523
# record_max_gap:[1670, 1523], x_prev_max: 1523, x_max: 1982, x_n:1428
# record_min_gap:[1202, 1258], x_prev_min: 1258, x_min: 1026, x_n:1428
# Before Round% 22,current_quantile:1774,  x_n:1428, record_min_gap: [1202, 1258], record_max_gap:[1670, 1523], min_gap:19, c_minus:19, c_plus:2  23
# c_minux+1: 20, seq_size*p: 20.7, round value: 21
# After Round% 22, current_quantile:1774, record_min_gap: [1202, 1258], record_max_gap:[1670, 1523], min_gap:19, c_minus:20, c_plus:2
# @@@@@@@ 23 [1670, 1523] 1523
# tk gap_before: [1244,1202]; gap_after: [1244,1258] 1244 1523
# record_max_gap:[1670, 1523], x_prev_max: 1523, x_max: 1982, x_n:1244
# record_min_gap:[1202, 1244], x_prev_min: 1244, x_min: 1026, x_n:1244
# Before Round% 23,current_quantile:1774,  x_n:1244, record_min_gap: [1202, 1244], record_max_gap:[1670, 1523], min_gap:19, c_minus:20, c_plus:2  24
# c_minux+1: 21, seq_size*p: 21.6, round value: 22
# After Round% 23, current_quantile:1774, record_min_gap: [1202, 1244], record_max_gap:[1670, 1523], min_gap:19, c_minus:21, c_plus:2
# @@@@@@@ 24 [1670, 1523] 1523
# record_max_gap:[1670, 1523], x_prev_max: 1523, x_max: 1982, x_n:1287
# record_min_gap:[1202, 1244], x_prev_min: 1244, x_min: 1026, x_n:1287
# Before Round% 24,current_quantile:1774,  x_n:1287, record_min_gap: [1202, 1244], record_max_gap:[1670, 1523], min_gap:19, c_minus:21, c_plus:2  25
# c_minux+1: 22, seq_size*p: 22.5, round value: 23
# After Round% 24, current_quantile:1774, record_min_gap: [1202, 1244], record_max_gap:[1670, 1523], min_gap:19, c_minus:22, c_plus:2
# @@@@@@@ 25 [1670, 1523] 1523
# j 1702
# record_max_gap:[1702, 1523], x_prev_max: 1523, x_max: 1982, x_n:1702
# record_min_gap:[1202, 1244], x_prev_min: 1244, x_min: 1026, x_n:1702
# Before Round% 25,current_quantile:1774,  x_n:1702, record_min_gap: [1202, 1244], record_max_gap:[1702, 1523], min_gap:19, c_minus:22, c_plus:2  26
# c_minux+1: 23, seq_size*p: 23.400000000000002, round value: 23
# After Round% 25, current_quantile:1774, record_min_gap: [1202, 1244], record_max_gap:[1702, 1523], min_gap:19, c_minus:23, c_plus:2
# @@@@@@@ 26 [1702, 1523] 1523
# j 1846
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1846
# record_min_gap:[1202, 1244], x_prev_min: 1244, x_min: 1026, x_n:1846
# Before Round% 26,current_quantile:1774,  x_n:1846, record_min_gap: [1202, 1244], record_max_gap:[1846, 1523], min_gap:19, c_minus:23, c_plus:2  27
# c_plus+1: 3, seq_size*(1-p): 2.6999999999999993
# ~~~~~~~~~~~ pluss 1774 19
# current_quantile 1793
# After Round% 26, current_quantile:1793, record_min_gap: [1202, 1244], record_max_gap:[1846, 1523], min_gap:19, c_minus:24, c_plus:2
# @@@@@@@ 27 [1846, 1523] 1523
# tk gap_before: [1224,1202]; gap_after: [1224,1244] 1224 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1224
# record_min_gap:[1202, 1224], x_prev_min: 1224, x_min: 1026, x_n:1224
# Before Round% 27,current_quantile:1793,  x_n:1224, record_min_gap: [1202, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:24, c_plus:2  28
# c_minux+1: 25, seq_size*p: 25.2, round value: 25
# After Round% 27, current_quantile:1793, record_min_gap: [1202, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:25, c_plus:2
# @@@@@@@ 28 [1846, 1523] 1523
# jjjj 1187 1224
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1187
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1187
# Before Round% 28,current_quantile:1793,  x_n:1187, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:25, c_plus:2  29
# c_minux+1: 26, seq_size*p: 26.1, round value: 26
# After Round% 28, current_quantile:1793, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:26, c_plus:2
# @@@@@@@ 29 [1846, 1523] 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1285
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1285
# Before Round% 29,current_quantile:1793,  x_n:1285, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:26, c_plus:2  30
# c_minux+1: 27, seq_size*p: 27.0, round value: 27
# ============= minus 1793 19
# After Round% 29, current_quantile:1774, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:26, c_plus:3
# @@@@@@@ 30 [1846, 1523] 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1353
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1353
# Before Round% 30,current_quantile:1774,  x_n:1353, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:26, c_plus:3  31
# c_minux+1: 27, seq_size*p: 27.900000000000002, round value: 28
# After Round% 30, current_quantile:1774, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:27, c_plus:3
# @@@@@@@ 31 [1846, 1523] 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1453
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1453
# Before Round% 31,current_quantile:1774,  x_n:1453, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:27, c_plus:3  32
# c_minux+1: 28, seq_size*p: 28.8, round value: 29
# After Round% 31, current_quantile:1774, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:28, c_plus:3
# @@@@@@@ 32 [1846, 1523] 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1354
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1354
# Before Round% 32,current_quantile:1774,  x_n:1354, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:28, c_plus:3  33
# c_minux+1: 29, seq_size*p: 29.7, round value: 30
# After Round% 32, current_quantile:1774, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:29, c_plus:3
# @@@@@@@ 33 [1846, 1523] 1523
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1462
# record_min_gap:[1187, 1224], x_prev_min: 1224, x_min: 1026, x_n:1462
# Before Round% 33,current_quantile:1774,  x_n:1462, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:29, c_plus:3  34
# c_minux+1: 30, seq_size*p: 30.6, round value: 31
# After Round% 33, current_quantile:1774, record_min_gap: [1187, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:30, c_plus:3
# @@@@@@@ 34 [1846, 1523] 1523
# jjjj 1204 1224
# record_max_gap:[1846, 1523], x_prev_max: 1523, x_max: 1982, x_n:1204
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1204
# Before Round% 34,current_quantile:1774,  x_n:1204, record_min_gap: [1204, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:30, c_plus:3  35
# c_minux+1: 31, seq_size*p: 31.5, round value: 32
# After Round% 34, current_quantile:1774, record_min_gap: [1204, 1224], record_max_gap:[1846, 1523], min_gap:19, c_minus:31, c_plus:3
# @@@@@@@ 35 [1846, 1523] 1523
# j 1939
# record_max_gap:[1939, 1523], x_prev_max: 1523, x_max: 1982, x_n:1939
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1939
# Before Round% 35,current_quantile:1774,  x_n:1939, record_min_gap: [1204, 1224], record_max_gap:[1939, 1523], min_gap:19, c_minus:31, c_plus:3  36
# c_plus+1: 4, seq_size*(1-p): 3.599999999999999
# ~~~~~~~~~~~ pluss 1774 19
# current_quantile 1793
# After Round% 35, current_quantile:1793, record_min_gap: [1204, 1224], record_max_gap:[1939, 1523], min_gap:19, c_minus:32, c_plus:3
# @@@@@@@ 36 [1939, 1523] 1523
# j 1947
# record_max_gap:[1947, 1523], x_prev_max: 1523, x_max: 1982, x_n:1947
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1947
# Before Round% 36,current_quantile:1793,  x_n:1947, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:32, c_plus:3  37
# c_plus+1: 4, seq_size*(1-p): 3.6999999999999993
# ~~~~~~~~~~~ pluss 1793 19
# current_quantile 1812
# After Round% 36, current_quantile:1812, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:33, c_plus:3
# @@@@@@@ 37 [1947, 1523] 1523
# record_max_gap:[1947, 1523], x_prev_max: 1523, x_max: 1982, x_n:1504
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1504
# Before Round% 37,current_quantile:1812,  x_n:1504, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:33, c_plus:3  38
# c_minux+1: 34, seq_size*p: 34.2, round value: 34
# After Round% 37, current_quantile:1812, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:34, c_plus:3
# @@@@@@@ 38 [1947, 1523] 1523
# record_max_gap:[1947, 1523], x_prev_max: 1523, x_max: 1982, x_n:1225
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1225
# Before Round% 38,current_quantile:1812,  x_n:1225, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:34, c_plus:3  39
# c_minux+1: 35, seq_size*p: 35.1, round value: 35
# After Round% 38, current_quantile:1812, record_min_gap: [1204, 1224], record_max_gap:[1947, 1523], min_gap:19, c_minus:35, c_plus:3
# @@@@@@@ 39 [1947, 1523] 1523
# j 1778
# record_max_gap:[1778, 1523], x_prev_max: 1523, x_max: 1982, x_n:1778
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1778
# Before Round% 39,current_quantile:1812,  x_n:1778, record_min_gap: [1204, 1224], record_max_gap:[1778, 1523], min_gap:19, c_minus:35, c_plus:3  40
# c_minux+1: 36, seq_size*p: 36.0, round value: 36
# ============= minus 1812 19
# After Round% 39, current_quantile:1793, record_min_gap: [1204, 1224], record_max_gap:[1778, 1523], min_gap:19, c_minus:35, c_plus:4
# @@@@@@@ 40 [1778, 1523] 1523
# j 1713
# record_max_gap:[1713, 1523], x_prev_max: 1523, x_max: 1982, x_n:1713
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1713
# Before Round% 40,current_quantile:1793,  x_n:1713, record_min_gap: [1204, 1224], record_max_gap:[1713, 1523], min_gap:19, c_minus:35, c_plus:4  41
# c_minux+1: 36, seq_size*p: 36.9, round value: 37
# After Round% 40, current_quantile:1793, record_min_gap: [1204, 1224], record_max_gap:[1713, 1523], min_gap:19, c_minus:36, c_plus:4
# @@@@@@@ 41 [1713, 1523] 1523
# k gap_before: [1523,1554] ; gap_after: [1554,1713] 1554 1523
# record_max_gap:[1713, 1554], x_prev_max: 1554, x_max: 1982, x_n:1554
# record_min_gap:[1204, 1224], x_prev_min: 1224, x_min: 1026, x_n:1554
# Before Round% 41,current_quantile:1793,  x_n:1554, record_min_gap: [1204, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:36, c_plus:4  42
# c_minux+1: 37, seq_size*p: 37.800000000000004, round value: 38
# After Round% 41, current_quantile:1793, record_min_gap: [1204, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:37, c_plus:4
# @@@@@@@ 42 [1713, 1554] 1554
# jjjj 1082 1224
# record_max_gap:[1713, 1554], x_prev_max: 1554, x_max: 1982, x_n:1082
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1082
# Before Round% 42,current_quantile:1793,  x_n:1082, record_min_gap: [1082, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:37, c_plus:4  43
# c_minux+1: 38, seq_size*p: 38.7, round value: 39
# After Round% 42, current_quantile:1793, record_min_gap: [1082, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:38, c_plus:4
# @@@@@@@ 43 [1713, 1554] 1554
# record_max_gap:[1713, 1554], x_prev_max: 1554, x_max: 1982, x_n:1354
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1354
# Before Round% 43,current_quantile:1793,  x_n:1354, record_min_gap: [1082, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:38, c_plus:4  44
# c_minux+1: 39, seq_size*p: 39.6, round value: 40
# After Round% 43, current_quantile:1793, record_min_gap: [1082, 1224], record_max_gap:[1713, 1554], min_gap:19, c_minus:39, c_plus:4
# @@@@@@@ 44 [1713, 1554] 1554
# j 1704
# record_max_gap:[1704, 1554], x_prev_max: 1554, x_max: 1982, x_n:1704
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1704
# Before Round% 44,current_quantile:1793,  x_n:1704, record_min_gap: [1082, 1224], record_max_gap:[1704, 1554], min_gap:19, c_minus:39, c_plus:4  45
# c_minux+1: 40, seq_size*p: 40.5, round value: 41
# After Round% 44, current_quantile:1793, record_min_gap: [1082, 1224], record_max_gap:[1704, 1554], min_gap:19, c_minus:40, c_plus:4
# @@@@@@@ 45 [1704, 1554] 1554
# record_max_gap:[1704, 1554], x_prev_max: 1554, x_max: 1982, x_n:1537
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1537
# Before Round% 45,current_quantile:1793,  x_n:1537, record_min_gap: [1082, 1224], record_max_gap:[1704, 1554], min_gap:17, c_minus:40, c_plus:4  46
# c_minux+1: 41, seq_size*p: 41.4, round value: 41
# After Round% 45, current_quantile:1793, record_min_gap: [1082, 1224], record_max_gap:[1704, 1554], min_gap:17, c_minus:41, c_plus:4
# @@@@@@@ 46 [1704, 1554] 1554
# k gap_before: [1554,1603] ; gap_after: [1603,1704] 1603 1554
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1982, x_n:1603
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1603
# Before Round% 46,current_quantile:1793,  x_n:1603, record_min_gap: [1082, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:41, c_plus:4  47
# c_minux+1: 42, seq_size*p: 42.300000000000004, round value: 42
# After Round% 46, current_quantile:1793, record_min_gap: [1082, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:42, c_plus:4
# @@@@@@@ 47 [1704, 1603] 1603
# --- x_n:1985, x_prev_max:1603, x_max:1982
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1985, x_n:1985
# record_min_gap:[1082, 1224], x_prev_min: 1224, x_min: 1026, x_n:1985
# Before Round% 47,current_quantile:1793,  x_n:1985, record_min_gap: [1082, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:42, c_plus:4  48
# c_plus+1: 5, seq_size*(1-p): 4.799999999999999
# ~~~~~~~~~~~ pluss 1793 17
# current_quantile 1810
# After Round% 47, current_quantile:1810, record_min_gap: [1082, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:43, c_plus:4
# @@@@@@@ 48 [1704, 1603] 1603
# jjjj 1038 1224
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1985, x_n:1038
# record_min_gap:[1038, 1224], x_prev_min: 1224, x_min: 1026, x_n:1038
# Before Round% 48,current_quantile:1810,  x_n:1038, record_min_gap: [1038, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:43, c_plus:4  49
# c_minux+1: 44, seq_size*p: 44.1, round value: 44
# After Round% 48, current_quantile:1810, record_min_gap: [1038, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:44, c_plus:4
# @@@@@@@ 49 [1704, 1603] 1603
# jjjj 1108 1224
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1985, x_n:1108
# record_min_gap:[1108, 1224], x_prev_min: 1224, x_min: 1026, x_n:1108
# Before Round% 49,current_quantile:1810,  x_n:1108, record_min_gap: [1108, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:44, c_plus:4  50
# c_minux+1: 45, seq_size*p: 45.0, round value: 45
# ============= minus 1810 17
# After Round% 49, current_quantile:1793, record_min_gap: [1108, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:44, c_plus:5
# @@@@@@@ 50 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1985, x_n:1283
# record_min_gap:[1108, 1224], x_prev_min: 1224, x_min: 1026, x_n:1283
# Before Round% 50,current_quantile:1793,  x_n:1283, record_min_gap: [1108, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:44, c_plus:5  51
# c_minux+1: 45, seq_size*p: 45.9, round value: 46
# After Round% 50, current_quantile:1793, record_min_gap: [1108, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:45, c_plus:5
# @@@@@@@ 51 [1704, 1603] 1603
# jjjj 1076 1224
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1985, x_n:1076
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1076
# Before Round% 51,current_quantile:1793,  x_n:1076, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:45, c_plus:5  52
# c_minux+1: 46, seq_size*p: 46.800000000000004, round value: 47
# After Round% 51, current_quantile:1793, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:46, c_plus:5
# @@@@@@@ 52 [1704, 1603] 1603
# --- x_n:1997, x_prev_max:1603, x_max:1985
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1997
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1997
# Before Round% 52,current_quantile:1793,  x_n:1997, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:46, c_plus:5  53
# c_plus+1: 6, seq_size*(1-p): 5.299999999999999
# ~~~~~~~~~~~ pluss 1793 17
# current_quantile 1810
# After Round% 52, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:47, c_plus:5
# @@@@@@@ 53 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1573
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1573
# Before Round% 53,current_quantile:1810,  x_n:1573, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:47, c_plus:5  54
# c_minux+1: 48, seq_size*p: 48.6, round value: 49
# After Round% 53, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:48, c_plus:5
# @@@@@@@ 54 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1466
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1466
# Before Round% 54,current_quantile:1810,  x_n:1466, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:48, c_plus:5  55
# c_minux+1: 49, seq_size*p: 49.5, round value: 50
# After Round% 54, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:49, c_plus:5
# @@@@@@@ 55 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1502
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1502
# Before Round% 55,current_quantile:1810,  x_n:1502, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:49, c_plus:5  56
# c_minux+1: 50, seq_size*p: 50.4, round value: 50
# After Round% 55, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:50, c_plus:5
# @@@@@@@ 56 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1492
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1492
# Before Round% 56,current_quantile:1810,  x_n:1492, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:50, c_plus:5  57
# c_minux+1: 51, seq_size*p: 51.300000000000004, round value: 51
# After Round% 56, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:51, c_plus:5
# @@@@@@@ 57 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1578
# record_min_gap:[1076, 1224], x_prev_min: 1224, x_min: 1026, x_n:1578
# Before Round% 57,current_quantile:1810,  x_n:1578, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:51, c_plus:5  58
# c_minux+1: 52, seq_size*p: 52.2, round value: 52
# After Round% 57, current_quantile:1810, record_min_gap: [1076, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:52, c_plus:5
# @@@@@@@ 58 [1704, 1603] 1603
# jjjj 1034 1224
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1034
# record_min_gap:[1034, 1224], x_prev_min: 1224, x_min: 1026, x_n:1034
# Before Round% 58,current_quantile:1810,  x_n:1034, record_min_gap: [1034, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:52, c_plus:5  59
# c_minux+1: 53, seq_size*p: 53.1, round value: 53
# After Round% 58, current_quantile:1810, record_min_gap: [1034, 1224], record_max_gap:[1704, 1603], min_gap:17, c_minus:53, c_plus:5
# @@@@@@@ 59 [1704, 1603] 1603
# tk gap_before: [1177,1034]; gap_after: [1177,1224] 1177 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1177
# record_min_gap:[1034, 1177], x_prev_min: 1177, x_min: 1026, x_n:1177
# Before Round% 59,current_quantile:1810,  x_n:1177, record_min_gap: [1034, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:53, c_plus:5  60
# c_minux+1: 54, seq_size*p: 54.0, round value: 54
# ============= minus 1810 17
# After Round% 59, current_quantile:1793, record_min_gap: [1034, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:53, c_plus:6
# @@@@@@@ 60 [1704, 1603] 1603
# jjjj 1080 1177
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1080
# record_min_gap:[1080, 1177], x_prev_min: 1177, x_min: 1026, x_n:1080
# Before Round% 60,current_quantile:1793,  x_n:1080, record_min_gap: [1080, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:53, c_plus:6  61
# c_minux+1: 54, seq_size*p: 54.9, round value: 55
# After Round% 60, current_quantile:1793, record_min_gap: [1080, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:54, c_plus:6
# @@@@@@@ 61 [1704, 1603] 1603
# jjjj 1068 1177
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1068
# record_min_gap:[1068, 1177], x_prev_min: 1177, x_min: 1026, x_n:1068
# Before Round% 61,current_quantile:1793,  x_n:1068, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:54, c_plus:6  62
# c_minux+1: 55, seq_size*p: 55.800000000000004, round value: 56
# After Round% 61, current_quantile:1793, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:55, c_plus:6
# @@@@@@@ 62 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1298
# record_min_gap:[1068, 1177], x_prev_min: 1177, x_min: 1026, x_n:1298
# Before Round% 62,current_quantile:1793,  x_n:1298, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:55, c_plus:6  63
# c_minux+1: 56, seq_size*p: 56.7, round value: 57
# After Round% 62, current_quantile:1793, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:56, c_plus:6
# @@@@@@@ 63 [1704, 1603] 1603
# record_max_gap:[1704, 1603], x_prev_max: 1603, x_max: 1997, x_n:1326
# record_min_gap:[1068, 1177], x_prev_min: 1177, x_min: 1026, x_n:1326
# Before Round% 63,current_quantile:1793,  x_n:1326, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:56, c_plus:6  64
# c_minux+1: 57, seq_size*p: 57.6, round value: 58
# After Round% 63, current_quantile:1793, record_min_gap: [1068, 1177], record_max_gap:[1704, 1603], min_gap:17, c_minus:57, c_plus:6
# @@@@@@@ 64 [1704, 1603] 1603
# k gap_before: [1603,1643] ; gap_after: [1643,1704] 1643 1603
# record_max_gap:[1704, 1643], x_prev_max: 1643, x_max: 1997, x_n:1643
# record_min_gap:[1068, 1177], x_prev_min: 1177, x_min: 1026, x_n:1643
# Before Round% 64,current_quantile:1793,  x_n:1643, record_min_gap: [1068, 1177], record_max_gap:[1704, 1643], min_gap:17, c_minus:57, c_plus:6  65
# c_minux+1: 58, seq_size*p: 58.5, round value: 59
# After Round% 64, current_quantile:1793, record_min_gap: [1068, 1177], record_max_gap:[1704, 1643], min_gap:17, c_minus:58, c_plus:6
# @@@@@@@ 65 [1704, 1643] 1643
# j 1702
# record_max_gap:[1702, 1643], x_prev_max: 1643, x_max: 1997, x_n:1702
# record_min_gap:[1068, 1177], x_prev_min: 1177, x_min: 1026, x_n:1702
# Before Round% 65,current_quantile:1793,  x_n:1702, record_min_gap: [1068, 1177], record_max_gap:[1702, 1643], min_gap:17, c_minus:58, c_plus:6  66
# c_minux+1: 59, seq_size*p: 59.4, round value: 59
# After Round% 65, current_quantile:1793, record_min_gap: [1068, 1177], record_max_gap:[1702, 1643], min_gap:17, c_minus:59, c_plus:6
# @@@@@@@ 66 [1702, 1643] 1643
# jjjj 1060 1177
# record_max_gap:[1702, 1643], x_prev_max: 1643, x_max: 1997, x_n:1060
# record_min_gap:[1060, 1177], x_prev_min: 1177, x_min: 1026, x_n:1060
# Before Round% 66,current_quantile:1793,  x_n:1060, record_min_gap: [1060, 1177], record_max_gap:[1702, 1643], min_gap:17, c_minus:59, c_plus:6  67
# c_minux+1: 60, seq_size*p: 60.300000000000004, round value: 60
# After Round% 66, current_quantile:1793, record_min_gap: [1060, 1177], record_max_gap:[1702, 1643], min_gap:17, c_minus:60, c_plus:6
# @@@@@@@ 67 [1702, 1643] 1643
# j 1708
# record_max_gap:[1708, 1643], x_prev_max: 1643, x_max: 1997, x_n:1708
# record_min_gap:[1060, 1177], x_prev_min: 1177, x_min: 1026, x_n:1708
# Before Round% 67,current_quantile:1793,  x_n:1708, record_min_gap: [1060, 1177], record_max_gap:[1708, 1643], min_gap:17, c_minus:60, c_plus:6  68
# c_minux+1: 61, seq_size*p: 61.2, round value: 61
# After Round% 67, current_quantile:1793, record_min_gap: [1060, 1177], record_max_gap:[1708, 1643], min_gap:17, c_minus:61, c_plus:6
# @@@@@@@ 68 [1708, 1643] 1643
# j 1710
# record_max_gap:[1710, 1643], x_prev_max: 1643, x_max: 1997, x_n:1710
# record_min_gap:[1060, 1177], x_prev_min: 1177, x_min: 1026, x_n:1710
# Before Round% 68,current_quantile:1793,  x_n:1710, record_min_gap: [1060, 1177], record_max_gap:[1710, 1643], min_gap:17, c_minus:61, c_plus:6  69
# c_minux+1: 62, seq_size*p: 62.1, round value: 62
# After Round% 68, current_quantile:1793, record_min_gap: [1060, 1177], record_max_gap:[1710, 1643], min_gap:17, c_minus:62, c_plus:6
# @@@@@@@ 69 [1710, 1643] 1643
# j 1710
# record_max_gap:[1710, 1643], x_prev_max: 1643, x_max: 1997, x_n:1710
# record_min_gap:[1060, 1177], x_prev_min: 1177, x_min: 1026, x_n:1710
# Before Round% 69,current_quantile:1793,  x_n:1710, record_min_gap: [1060, 1177], record_max_gap:[1710, 1643], min_gap:17, c_minus:62, c_plus:6  70
# c_minux+1: 63, seq_size*p: 63.0, round value: 63
# ============= minus 1793 17
# After Round% 69, current_quantile:1776, record_min_gap: [1060, 1177], record_max_gap:[1710, 1643], min_gap:17, c_minus:62, c_plus:7
# @@@@@@@ 70 [1710, 1643] 1643
# k gap_before: [1643,1645] ; gap_after: [1645,1710] 1645 1643
# record_max_gap:[1710, 1645], x_prev_max: 1645, x_max: 1997, x_n:1645
# record_min_gap:[1060, 1177], x_prev_min: 1177, x_min: 1026, x_n:1645
# Before Round% 70,current_quantile:1776,  x_n:1645, record_min_gap: [1060, 1177], record_max_gap:[1710, 1645], min_gap:2, c_minus:62, c_plus:7  71
# c_minux+1: 63, seq_size*p: 63.9, round value: 64
# After Round% 70, current_quantile:1776, record_min_gap: [1060, 1177], record_max_gap:[1710, 1645], min_gap:2, c_minus:63, c_plus:7
# @@@@@@@ 71 [1710, 1645] 1645
# tk gap_before: [1170,1060]; gap_after: [1170,1177] 1170 1645
# record_max_gap:[1710, 1645], x_prev_max: 1645, x_max: 1997, x_n:1170
# record_min_gap:[1060, 1170], x_prev_min: 1170, x_min: 1026, x_n:1170
# Before Round% 71,current_quantile:1776,  x_n:1170, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:63, c_plus:7  72
# c_minux+1: 64, seq_size*p: 64.8, round value: 65
# After Round% 71, current_quantile:1776, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:64, c_plus:7
# @@@@@@@ 72 [1710, 1645] 1645
# record_max_gap:[1710, 1645], x_prev_max: 1645, x_max: 1997, x_n:1497
# record_min_gap:[1060, 1170], x_prev_min: 1170, x_min: 1026, x_n:1497
# Before Round% 72,current_quantile:1776,  x_n:1497, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:64, c_plus:7  73
# c_minux+1: 65, seq_size*p: 65.7, round value: 66
# After Round% 72, current_quantile:1776, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:65, c_plus:7
# @@@@@@@ 73 [1710, 1645] 1645
# record_max_gap:[1710, 1645], x_prev_max: 1645, x_max: 1997, x_n:1321
# record_min_gap:[1060, 1170], x_prev_min: 1170, x_min: 1026, x_n:1321
# Before Round% 73,current_quantile:1776,  x_n:1321, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:65, c_plus:7  74
# c_minux+1: 66, seq_size*p: 66.60000000000001, round value: 67
# After Round% 73, current_quantile:1776, record_min_gap: [1060, 1170], record_max_gap:[1710, 1645], min_gap:2, c_minus:66, c_plus:7
# @@@@@@@ 74 [1710, 1645] 1645
# j 1879
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1879
# record_min_gap:[1060, 1170], x_prev_min: 1170, x_min: 1026, x_n:1879
# Before Round% 74,current_quantile:1776,  x_n:1879, record_min_gap: [1060, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:66, c_plus:7  75
# c_plus+1: 8, seq_size*(1-p): 7.499999999999998
# ~~~~~~~~~~~ pluss 1776 2
# current_quantile 1778
# After Round% 74, current_quantile:1778, record_min_gap: [1060, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:67, c_plus:7
# @@@@@@@ 75 [1879, 1645] 1645
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1439
# record_min_gap:[1060, 1170], x_prev_min: 1170, x_min: 1026, x_n:1439
# Before Round% 75,current_quantile:1778,  x_n:1439, record_min_gap: [1060, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:67, c_plus:7  76
# c_minux+1: 68, seq_size*p: 68.4, round value: 68
# After Round% 75, current_quantile:1778, record_min_gap: [1060, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:68, c_plus:7
# @@@@@@@ 76 [1879, 1645] 1645
# jjjj 1089 1170
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1089
# record_min_gap:[1089, 1170], x_prev_min: 1170, x_min: 1026, x_n:1089
# Before Round% 76,current_quantile:1778,  x_n:1089, record_min_gap: [1089, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:68, c_plus:7  77
# c_minux+1: 69, seq_size*p: 69.3, round value: 69
# After Round% 76, current_quantile:1778, record_min_gap: [1089, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:69, c_plus:7
# @@@@@@@ 77 [1879, 1645] 1645
# jjjj 1070 1170
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1070
# record_min_gap:[1070, 1170], x_prev_min: 1170, x_min: 1026, x_n:1070
# Before Round% 77,current_quantile:1778,  x_n:1070, record_min_gap: [1070, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:69, c_plus:7  78
# c_minux+1: 70, seq_size*p: 70.2, round value: 70
# After Round% 77, current_quantile:1778, record_min_gap: [1070, 1170], record_max_gap:[1879, 1645], min_gap:2, c_minus:70, c_plus:7
# @@@@@@@ 78 [1879, 1645] 1645
# tk gap_before: [1129,1070]; gap_after: [1129,1170] 1129 1645
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1129
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1026, x_n:1129
# Before Round% 78,current_quantile:1778,  x_n:1129, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:70, c_plus:7  79
# c_minux+1: 71, seq_size*p: 71.10000000000001, round value: 71
# After Round% 78, current_quantile:1778, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:71, c_plus:7
# @@@@@@@ 79 [1879, 1645] 1645
# ++= x_n:1008, x_prev_min:1129, x_min: 1026
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1008
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1008, x_n:1008
# Before Round% 79,current_quantile:1778,  x_n:1008, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:71, c_plus:7  80
# c_minux+1: 72, seq_size*p: 72.0, round value: 72
# ============= minus 1778 2
# After Round% 79, current_quantile:1776, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:71, c_plus:8
# @@@@@@@ 80 [1879, 1645] 1645
# record_max_gap:[1879, 1645], x_prev_max: 1645, x_max: 1997, x_n:1141
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1008, x_n:1141
# Before Round% 80,current_quantile:1776,  x_n:1141, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:71, c_plus:8  81
# c_minux+1: 72, seq_size*p: 72.9, round value: 73
# After Round% 80, current_quantile:1776, record_min_gap: [1070, 1129], record_max_gap:[1879, 1645], min_gap:2, c_minus:72, c_plus:8
# @@@@@@@ 81 [1879, 1645] 1645
# j 1965
# record_max_gap:[1965, 1645], x_prev_max: 1645, x_max: 1997, x_n:1965
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1008, x_n:1965
# Before Round% 81,current_quantile:1776,  x_n:1965, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:72, c_plus:8  82
# c_plus+1: 9, seq_size*(1-p): 8.199999999999998
# ~~~~~~~~~~~ pluss 1776 2
# current_quantile 1778
# After Round% 81, current_quantile:1778, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:73, c_plus:8
# @@@@@@@ 82 [1965, 1645] 1645
# record_max_gap:[1965, 1645], x_prev_max: 1645, x_max: 1997, x_n:1522
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1008, x_n:1522
# Before Round% 82,current_quantile:1778,  x_n:1522, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:73, c_plus:8  83
# c_minux+1: 74, seq_size*p: 74.7, round value: 75
# After Round% 82, current_quantile:1778, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:74, c_plus:8
# @@@@@@@ 83 [1965, 1645] 1645
# record_max_gap:[1965, 1645], x_prev_max: 1645, x_max: 1997, x_n:1373
# record_min_gap:[1070, 1129], x_prev_min: 1129, x_min: 1008, x_n:1373
# Before Round% 83,current_quantile:1778,  x_n:1373, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:74, c_plus:8  84
# c_minux+1: 75, seq_size*p: 75.60000000000001, round value: 76
# After Round% 83, current_quantile:1778, record_min_gap: [1070, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:75, c_plus:8
# @@@@@@@ 84 [1965, 1645] 1645
# jjjj 1026 1129
# record_max_gap:[1965, 1645], x_prev_max: 1645, x_max: 1997, x_n:1026
# record_min_gap:[1026, 1129], x_prev_min: 1129, x_min: 1008, x_n:1026
# Before Round% 84,current_quantile:1778,  x_n:1026, record_min_gap: [1026, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:75, c_plus:8  85
# c_minux+1: 76, seq_size*p: 76.5, round value: 77
# After Round% 84, current_quantile:1778, record_min_gap: [1026, 1129], record_max_gap:[1965, 1645], min_gap:2, c_minus:76, c_plus:8
# @@@@@@@ 85 [1965, 1645] 1645
# j 1893
# record_max_gap:[1893, 1645], x_prev_max: 1645, x_max: 1997, x_n:1893
# record_min_gap:[1026, 1129], x_prev_min: 1129, x_min: 1008, x_n:1893
# Before Round% 85,current_quantile:1778,  x_n:1893, record_min_gap: [1026, 1129], record_max_gap:[1893, 1645], min_gap:2, c_minus:76, c_plus:8  86
# c_plus+1: 9, seq_size*(1-p): 8.599999999999998
# ~~~~~~~~~~~ pluss 1778 2
# current_quantile 1780
# After Round% 85, current_quantile:1780, record_min_gap: [1026, 1129], record_max_gap:[1893, 1645], min_gap:2, c_minus:77, c_plus:8
# @@@@@@@ 86 [1893, 1645] 1645
# j 1853
# record_max_gap:[1853, 1645], x_prev_max: 1645, x_max: 1997, x_n:1853
# record_min_gap:[1026, 1129], x_prev_min: 1129, x_min: 1008, x_n:1853
# Before Round% 86,current_quantile:1780,  x_n:1853, record_min_gap: [1026, 1129], record_max_gap:[1853, 1645], min_gap:2, c_minus:77, c_plus:8  87
# c_plus+1: 9, seq_size*(1-p): 8.699999999999998
# ~~~~~~~~~~~ pluss 1780 2
# current_quantile 1782
# After Round% 86, current_quantile:1782, record_min_gap: [1026, 1129], record_max_gap:[1853, 1645], min_gap:2, c_minus:78, c_plus:8
# @@@@@@@ 87 [1853, 1645] 1645
# tk gap_before: [1117,1026]; gap_after: [1117,1129] 1117 1645
# record_max_gap:[1853, 1645], x_prev_max: 1645, x_max: 1997, x_n:1117
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1117
# Before Round% 87,current_quantile:1782,  x_n:1117, record_min_gap: [1026, 1117], record_max_gap:[1853, 1645], min_gap:2, c_minus:78, c_plus:8  88
# c_minux+1: 79, seq_size*p: 79.2, round value: 79
# After Round% 87, current_quantile:1782, record_min_gap: [1026, 1117], record_max_gap:[1853, 1645], min_gap:2, c_minus:79, c_plus:8
# @@@@@@@ 88 [1853, 1645] 1645
# record_max_gap:[1853, 1645], x_prev_max: 1645, x_max: 1997, x_n:1514
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1514
# Before Round% 88,current_quantile:1782,  x_n:1514, record_min_gap: [1026, 1117], record_max_gap:[1853, 1645], min_gap:2, c_minus:79, c_plus:8  89
# c_minux+1: 80, seq_size*p: 80.10000000000001, round value: 80
# After Round% 88, current_quantile:1782, record_min_gap: [1026, 1117], record_max_gap:[1853, 1645], min_gap:2, c_minus:80, c_plus:8
# @@@@@@@ 89 [1853, 1645] 1645
# k gap_before: [1645,1709] ; gap_after: [1709,1853] 1709 1645
# record_max_gap:[1853, 1709], x_prev_max: 1709, x_max: 1997, x_n:1709
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1709
# Before Round% 89,current_quantile:1782,  x_n:1709, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:80, c_plus:8  90
# c_minux+1: 81, seq_size*p: 81.0, round value: 81
# ============= minus 1782 2
# After Round% 89, current_quantile:1780, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:80, c_plus:9
# @@@@@@@ 90 [1853, 1709] 1709
# record_max_gap:[1853, 1709], x_prev_max: 1709, x_max: 1997, x_n:1125
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1125
# Before Round% 90,current_quantile:1780,  x_n:1125, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:80, c_plus:9  91
# c_minux+1: 81, seq_size*p: 81.9, round value: 82
# After Round% 90, current_quantile:1780, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:81, c_plus:9
# @@@@@@@ 91 [1853, 1709] 1709
# record_max_gap:[1853, 1709], x_prev_max: 1709, x_max: 1997, x_n:1432
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1432
# Before Round% 91,current_quantile:1780,  x_n:1432, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:81, c_plus:9  92
# c_minux+1: 82, seq_size*p: 82.8, round value: 83
# After Round% 91, current_quantile:1780, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:82, c_plus:9
# @@@@@@@ 92 [1853, 1709] 1709
# record_max_gap:[1853, 1709], x_prev_max: 1709, x_max: 1997, x_n:1523
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1523
# Before Round% 92,current_quantile:1780,  x_n:1523, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:82, c_plus:9  93
# c_minux+1: 83, seq_size*p: 83.7, round value: 84
# After Round% 92, current_quantile:1780, record_min_gap: [1026, 1117], record_max_gap:[1853, 1709], min_gap:2, c_minus:83, c_plus:9
# @@@@@@@ 93 [1853, 1709] 1709
# j 1968
# record_max_gap:[1968, 1709], x_prev_max: 1709, x_max: 1997, x_n:1968
# record_min_gap:[1026, 1117], x_prev_min: 1117, x_min: 1008, x_n:1968
# ...
# @@@@@@@ 179 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1283
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1283
# Before Round% 179,current_quantile:1958,  x_n:1283, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:161, c_plus:17  180
# c_minux+1: 162, seq_size*p: 162.0, round value: 162
# ============= minus 1958 2
# After Round% 179, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:161, c_plus:18
# @@@@@@@ 180 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1207
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1207
# Before Round% 180,current_quantile:1956,  x_n:1207, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:161, c_plus:18  181
# c_minux+1: 162, seq_size*p: 162.9, round value: 163
# After Round% 180, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:162, c_plus:18
# @@@@@@@ 181 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1533
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1533
# Before Round% 181,current_quantile:1956,  x_n:1533, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:162, c_plus:18  182
# c_minux+1: 163, seq_size*p: 163.8, round value: 164
# After Round% 181, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:163, c_plus:18
# @@@@@@@ 182 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1334
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1334
# Before Round% 182,current_quantile:1956,  x_n:1334, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:163, c_plus:18  183
# c_minux+1: 164, seq_size*p: 164.70000000000002, round value: 165
# After Round% 182, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:164, c_plus:18
# @@@@@@@ 183 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1935
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1935
# Before Round% 183,current_quantile:1956,  x_n:1935, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:164, c_plus:18  184
# c_minux+1: 165, seq_size*p: 165.6, round value: 166
# After Round% 183, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:165, c_plus:18
# @@@@@@@ 184 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1305
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1305
# Before Round% 184,current_quantile:1956,  x_n:1305, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:165, c_plus:18  185
# c_minux+1: 166, seq_size*p: 166.5, round value: 167
# After Round% 184, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:166, c_plus:18
# @@@@@@@ 185 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1842
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1842
# Before Round% 185,current_quantile:1956,  x_n:1842, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:166, c_plus:18  186
# c_minux+1: 167, seq_size*p: 167.4, round value: 167
# After Round% 185, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:167, c_plus:18
# @@@@@@@ 186 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1470
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1470
# Before Round% 186,current_quantile:1956,  x_n:1470, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:167, c_plus:18  187
# c_minux+1: 168, seq_size*p: 168.3, round value: 168
# After Round% 186, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:168, c_plus:18
# @@@@@@@ 187 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1310
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1310
# Before Round% 187,current_quantile:1956,  x_n:1310, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:168, c_plus:18  188
# c_minux+1: 169, seq_size*p: 169.20000000000002, round value: 169
# After Round% 187, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:169, c_plus:18
# @@@@@@@ 188 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1440
# record_min_gap:[1022, 1065], x_prev_min: 1065, x_min: 1008, x_n:1440
# Before Round% 188,current_quantile:1956,  x_n:1440, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:169, c_plus:18  189
# c_minux+1: 170, seq_size*p: 170.1, round value: 170
# After Round% 188, current_quantile:1956, record_min_gap: [1022, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:170, c_plus:18
# @@@@@@@ 189 [1995, 1979] 1979
# jjjj 1023 1065
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1023
# record_min_gap:[1023, 1065], x_prev_min: 1065, x_min: 1008, x_n:1023
# Before Round% 189,current_quantile:1956,  x_n:1023, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:170, c_plus:18  190
# c_minux+1: 171, seq_size*p: 171.0, round value: 171
# ============= minus 1956 2
# After Round% 189, current_quantile:1954, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:170, c_plus:19
# @@@@@@@ 190 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1099
# record_min_gap:[1023, 1065], x_prev_min: 1065, x_min: 1008, x_n:1099
# Before Round% 190,current_quantile:1954,  x_n:1099, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:170, c_plus:19  191
# c_minux+1: 171, seq_size*p: 171.9, round value: 172
# After Round% 190, current_quantile:1954, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:171, c_plus:19
# @@@@@@@ 191 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1350
# record_min_gap:[1023, 1065], x_prev_min: 1065, x_min: 1008, x_n:1350
# Before Round% 191,current_quantile:1954,  x_n:1350, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:171, c_plus:19  192
# c_minux+1: 172, seq_size*p: 172.8, round value: 173
# After Round% 191, current_quantile:1954, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:172, c_plus:19
# @@@@@@@ 192 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1114
# record_min_gap:[1023, 1065], x_prev_min: 1065, x_min: 1008, x_n:1114
# Before Round% 192,current_quantile:1954,  x_n:1114, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:172, c_plus:19  193
# c_minux+1: 173, seq_size*p: 173.70000000000002, round value: 174
# After Round% 192, current_quantile:1954, record_min_gap: [1023, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:173, c_plus:19
# @@@@@@@ 193 [1995, 1979] 1979
# jjjj 1021 1065
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1021
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1021
# Before Round% 193,current_quantile:1954,  x_n:1021, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:173, c_plus:19  194
# c_minux+1: 174, seq_size*p: 174.6, round value: 175
# After Round% 193, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:174, c_plus:19
# @@@@@@@ 194 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1075
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1075
# Before Round% 194,current_quantile:1954,  x_n:1075, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:174, c_plus:19  195
# c_minux+1: 175, seq_size*p: 175.5, round value: 176
# After Round% 194, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:175, c_plus:19
# @@@@@@@ 195 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1390
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1390
# Before Round% 195,current_quantile:1954,  x_n:1390, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:175, c_plus:19  196
# c_minux+1: 176, seq_size*p: 176.4, round value: 176
# After Round% 195, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:176, c_plus:19
# @@@@@@@ 196 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1263
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1263
# Before Round% 196,current_quantile:1954,  x_n:1263, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:176, c_plus:19  197
# c_minux+1: 177, seq_size*p: 177.3, round value: 177
# After Round% 196, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:177, c_plus:19
# @@@@@@@ 197 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1179
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1179
# Before Round% 197,current_quantile:1954,  x_n:1179, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:177, c_plus:19  198
# c_minux+1: 178, seq_size*p: 178.20000000000002, round value: 178
# After Round% 197, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:178, c_plus:19
# @@@@@@@ 198 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1693
# record_min_gap:[1021, 1065], x_prev_min: 1065, x_min: 1008, x_n:1693
# Before Round% 198,current_quantile:1954,  x_n:1693, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:178, c_plus:19  199
# c_minux+1: 179, seq_size*p: 179.1, round value: 179
# After Round% 198, current_quantile:1954, record_min_gap: [1021, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:179, c_plus:19
# @@@@@@@ 199 [1995, 1979] 1979
# jjjj 1038 1065
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1038
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1038
# Before Round% 199,current_quantile:1954,  x_n:1038, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:179, c_plus:19  200
# c_minux+1: 180, seq_size*p: 180.0, round value: 180
# ============= minus 1954 2
# After Round% 199, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:179, c_plus:20
# @@@@@@@ 200 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1850
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1850
# Before Round% 200,current_quantile:1952,  x_n:1850, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:179, c_plus:20  201
# c_minux+1: 180, seq_size*p: 180.9, round value: 181
# After Round% 200, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:180, c_plus:20
# @@@@@@@ 201 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1095
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1095
# Before Round% 201,current_quantile:1952,  x_n:1095, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:180, c_plus:20  202
# c_minux+1: 181, seq_size*p: 181.8, round value: 182
# After Round% 201, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:181, c_plus:20
# @@@@@@@ 202 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1387
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1387
# Before Round% 202,current_quantile:1952,  x_n:1387, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:181, c_plus:20  203
# c_minux+1: 182, seq_size*p: 182.70000000000002, round value: 183
# After Round% 202, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:182, c_plus:20
# @@@@@@@ 203 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1911
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1911
# Before Round% 203,current_quantile:1952,  x_n:1911, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:182, c_plus:20  204
# c_minux+1: 183, seq_size*p: 183.6, round value: 184
# After Round% 203, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:183, c_plus:20
# @@@@@@@ 204 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1762
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1762
# Before Round% 204,current_quantile:1952,  x_n:1762, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:183, c_plus:20  205
# c_minux+1: 184, seq_size*p: 184.5, round value: 185
# After Round% 204, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:184, c_plus:20
# @@@@@@@ 205 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1640
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1640
# Before Round% 205,current_quantile:1952,  x_n:1640, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:184, c_plus:20  206
# c_minux+1: 185, seq_size*p: 185.4, round value: 185
# After Round% 205, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:185, c_plus:20
# @@@@@@@ 206 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1741
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1741
# Before Round% 206,current_quantile:1952,  x_n:1741, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:185, c_plus:20  207
# c_minux+1: 186, seq_size*p: 186.3, round value: 186
# After Round% 206, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:186, c_plus:20
# @@@@@@@ 207 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1752
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1752
# Before Round% 207,current_quantile:1952,  x_n:1752, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:186, c_plus:20  208
# c_minux+1: 187, seq_size*p: 187.20000000000002, round value: 187
# After Round% 207, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:187, c_plus:20
# @@@@@@@ 208 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1109
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1109
# Before Round% 208,current_quantile:1952,  x_n:1109, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:187, c_plus:20  209
# c_minux+1: 188, seq_size*p: 188.1, round value: 188
# After Round% 208, current_quantile:1952, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:188, c_plus:20
# @@@@@@@ 209 [1995, 1979] 1979
# record_max_gap:[1995, 1979], x_prev_max: 1979, x_max: 1997, x_n:1731
# record_min_gap:[1038, 1065], x_prev_min: 1065, x_min: 1008, x_n:1731
# Before Round% 209,current_quantile:1952,  x_n:1731, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:188, c_plus:20  210
# c_minux+1: 189, seq_size*p: 189.0, round value: 189
# ============= minus 1952 2
# After Round% 209, current_quantile:1950, record_min_gap: [1038, 1065], record_max_gap:[1995, 1979], min_gap:2, c_minus:188, c_plus:21

# %%
np.percentile(append_random_sequence, 90)
# Out:
# 1863.3

# %%
print(append_random_sequence)
sorted_random_sequence = sorted(append_random_sequence)
print(sorted_random_sequence)
print("totel len: {}, p90 len: {}".format(len(sorted_random_sequence),int(0.9 * len(sorted_random_sequence))))
p90_value = sorted_random_sequence[int(0.9 * len(sorted_random_sequence))]
print(p90_value)
# Out:
# [1896 1026 1367 1389 1365 1752 1651 1380 1132 1437 1341 1140 1202 1290
#  1794 1258 1716 1418 1982 1488 1670 1523 1428 1244 1287 1702 1846 1224
#  1187 1285 1353 1453 1354 1462 1204 1939 1947 1504 1225 1778 1713 1554
#  1082 1354 1704 1537 1603 1985 1038 1108 1283 1076 1997 1573 1466 1502
#  1492 1578 1034 1177 1080 1068 1298 1326 1643 1702 1060 1708 1710 1710
#  1645 1170 1497 1321 1879 1439 1089 1070 1129 1008 1141 1965 1522 1373
#  1026 1893 1853 1117 1514 1709 1125 1432 1523 1968 1375 1224 1302 1173
#  1473 1111 1780 1538 1147 1757 1694 1866 1966 1630 1701 1782 1599 1752
#  1464 1013 1914 1082 1459 1028 1282 1592 1806 1093 1696 1256 1692 1187
#  1395 1317 1758 1227 1047 1474 1282 1391 1314 1345 1496 1708 1979 1093
#  1013 1168 1719 1191 1552 1185 1250 1033 1106 1509 1067 1919 1048 1380
#  1634 1280 1150 1096 1863 1995 1308 1065 1476 1223 1494 1134 1602 1802
#  1937 1022 1316 1143 1092 1115 1235 1907 1685 1949 1831 1283 1207 1533
#  1334 1935 1305 1842 1470 1310 1440 1023 1099 1350 1114 1021 1075 1390
#  1263 1179 1693 1038 1850 1095 1387 1911 1762 1640 1741 1752 1109 1731]
# [1008, 1013, 1013, 1021, 1022, 1023, 1026, 1026, 1028, 1033, 1034, 1038, 1038, 1047, 1048, 1060, 1065, 1067, 1068, 1070, 1075, 1076, 1080, 1082, 1082, 1089, 1092, 1093, 1093, 1095, 1096, 1099, 1106, 1108, 1109, 1111, 1114, 1115, 1117, 1125, 1129, 1132, 1134, 1140, 1141, 1143, 1147, 1150, 1168, 1170, 1173, 1177, 1179, 1185, 1187, 1187, 1191, 1202, 1204, 1207, 1223, 1224, 1224, 1225, 1227, 1235, 1244, 1250, 1256, 1258, 1263, 1280, 1282, 1282, 1283, 1283, 1285, 1287, 1290, 1298, 1302, 1305, 1308, 1310, 1314, 1316, 1317, 1321, 1326, 1334, 1341, 1345, 1350, 1353, 1354, 1354, 1365, 1367, 1373, 1375, 1380, 1380, 1387, 1389, 1390, 1391, 1395, 1418, 1428, 1432, 1437, 1439, 1440, 1453, 1459, 1462, 1464, 1466, 1470, 1473, 1474, 1476, 1488, 1492, 1494, 1496, 1497, 1502, 1504, 1509, 1514, 1522, 1523, 1523, 1533, 1537, 1538, 1552, 1554, 1573, 1578, 1592, 1599, 1602, 1603, 1630, 1634, 1640, 1643, 1645, 1651, 1670, 1685, 1692, 1693, 1694, 1696, 1701, 1702, 1702, 1704, 1708, 1708, 1709, 1710, 1710, 1713, 1716, 1719, 1731, 1741, 1752, 1752, 1752, 1757, 1758, 1762, 1778, 1780, 1782, 1794, 1802, 1806, 1831, 1842, 1846, 1850, 1853, 1863, 1866, 1879, 1893, 1896, 1907, 1911, 1914, 1919, 1935, 1937, 1939, 1947, 1949, 1965, 1966, 1968, 1979, 1982, 1985, 1995, 1997]
# totel len: 210, p90 len: 189
# 1866

# %%
random_sequence = np.append(random_sequence, 10000)

# %%
random_sequence[50] = 10000
print(random_sequence)
# Out:
# [  146   186   185   116    74    39   197   164   173    67    83   104
#    162   130   128    42    61    62    87    71   184    58   130    62
#    134   154   110   152    97   171    71    16    40    97   143   150
#     75   121   113    90   109   151   103    74   151    84   173   120
#     93   119 10000   170   112   119    73    57   118    87   112   123
#     95    77   133    23   122    65   105    93   167   153   174    94
#    121    20    77   107    86    29    47    13   134   149    28    40
#    138   158   126    20    24   171    92    49    11    74   176    96
#    187   155    29   167]

# %%
sorted_random_sequence = sorted(random_sequence)

# %%
sorted_seq = sorted(np.array([1,1,1,2,4,3,100]))
print(np.percentile(sorted_seq, 90))
# Out:
# 42.400000000000034

# %%
sorted_seq
# Out:
# [1, 1, 1, 2, 3, 4, 100]

# %%
p90_value = sorted_seq[int(0.8 * len(sorted_seq))]
print(p90_value)
# Out:
# 4
